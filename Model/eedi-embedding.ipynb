# %%
# %%time
# !pip uninstall -y torch
# !pip install -q --no-index --find-links=/kaggle/input/making-wheels-of-necessary-packages-for-vllm vllm
# !pip install -q -U /kaggle/input/vllm-t4-fix/grpcio-1.62.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# !pip install -q -U /kaggle/input/vllm-t4-fix/ray-2.11.0-cp310-cp310-manylinux2014_x86_64.whl
# !pip install -q --no-deps --no-index /kaggle/input/hf-libraries/sentence-transformers/sentence_transformers-3.1.0-py3-none-any.whl
# !pip install --no-deps --no-index /kaggle/input/logits-processor-zoo/logits_processor_zoo-0.1.0-py3-none-any.whl
# Out:
# Found existing installation: torch 2.4.0
# Uninstalling torch-2.4.0:
#   Successfully uninstalled torch-2.4.0
# Processing /kaggle/input/logits-processor-zoo/logits_processor_zoo-0.1.0-py3-none-any.whl
# Installing collected packages: logits-processor-zoo
# Successfully installed logits-processor-zoo-0.1.0
# CPU times: user 1.77 s, sys: 407 ms, total: 2.18 s
# Wall time: 2min 24s

# %%
# !pip install transformers peft accelerate \
    -q -U --no-index --find-links /kaggle/input/lmsys-wheel-files

# %%
# %%capture
# !pip install --no-index /kaggle/input/bitsandbytes0-42-0/bitsandbytes-0.42.0-py3-none-any.whl --find-links=/kaggle/input/bitsandbytes0-42-0
# !pip install --no-index  /kaggle/input/bitsandbytes0-42-0/optimum-1.21.2-py3-none-any.whl --find-links=/kaggle/input/bitsandbytes0-42-0
# !pip install --no-index  /kaggle/input/bitsandbytes0-42-0/auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl --find-links=/kaggle/input/bitsandbytes0-42-0

# %% [markdown]
# ### Embedding using 7B LLM

# %%
import pandas as pd
import numpy as np
full_df = pd.read_csv("/kaggle/input/eedi-mining-misconceptions-in-mathematics/train.csv")


rows = []
for idx, row in full_df.iterrows():
    for option in ["A", "B", "C", "D"]:
        if option == row.CorrectAnswer:
            continue
        # simply filter out all data samples without MisconceptionId
        if np.isnan(row[f"Misconception{option}Id"]):
            continue
        correct_answer = row[f"Answer{row.CorrectAnswer}Text"]
        
        query_text =f"###question###:{row['SubjectName']}-{row['ConstructName']}-{row['QuestionText']}\n###Correct Answer###:{correct_answer}\n###Misconcepte Incorrect answer###:{option}.{row[f'Answer{option}Text']}"
        rows.append({"query_text": query_text, 
                     "QuestionId_Answer": f"{row.QuestionId}_{option}",
                     "ConstructName": row.ConstructName,
                     "SubjectName": row.SubjectName,
                     "QuestionText": row.QuestionText,
                     "correct_answer": correct_answer,
                     "incorrect_answer": row[f"Answer{option}Text"],
                     "MisconceptionID":row[f"Misconception{option}Id"]
                     })

df = pd.DataFrame(rows)
df.head()
df.to_csv("/kaggle/working/train_query.csv")

# %%
# Code for Model Loading
import torch
from numpy.linalg import norm
import torch.nn.functional as F
from torch import Tensor
from transformers import AutoTokenizer, AutoModel,BitsAndBytesConfig
from peft import (
    LoraConfig,
    get_peft_model,
)

def batch_to_device(batch, target_device):
    """
    send a pytorch batch to a device (CPU/GPU)
    """
    for key in batch:
        if isinstance(batch[key], Tensor):
            batch[key] = batch[key].to(target_device)
    return batch

def last_token_pool(last_hidden_states: Tensor,
                    attention_mask: Tensor) -> Tensor:
    left_padding = (attention_mask[:, -1].sum() == attention_mask.shape[0])
    if left_padding:
        return last_hidden_states[:, -1]
    else:
        sequence_lengths = attention_mask.sum(dim=1) - 1
        batch_size = last_hidden_states.shape[0]
        return last_hidden_states[torch.arange(batch_size, device=last_hidden_states.device), sequence_lengths]

def get_detailed_instruct(task_description: str, query: str) -> str:
    return f'Instruct: {task_description}\nQuery: {query}'

def inference(df, model, tokenizer, device):
    batch_size = 16
    max_length = 512
    sentences = list(df['query_text'].values)

    all_embeddings = []
    length_sorted_idx = np.argsort([-len(sen) for sen in sentences])
    sentences_sorted = [sentences[idx] for idx in length_sorted_idx]
    for start_index in trange(0, len(sentences), batch_size, desc="Batches", disable=False):
        print(f"Processing batch {start_index}/{len(sentences)}")
        sentences_batch = sentences_sorted[start_index: start_index + batch_size]
        features = tokenizer(sentences_batch, max_length=max_length, padding=True, truncation=True,
                             return_tensors="pt")
        features = batch_to_device(features, device)
        with torch.no_grad():
            outputs = model.model(**features)
            embeddings = last_token_pool(outputs.last_hidden_state, features['attention_mask'])
            embeddings = torch.nn.functional.normalize(embeddings, dim=-1)
            embeddings = embeddings.detach().cpu().numpy().tolist()
        all_embeddings.extend(embeddings)

    all_embeddings = [np.array(all_embeddings[idx]).reshape(1, -1) for idx in np.argsort(length_sorted_idx)]

    return np.concatenate(all_embeddings, axis=0)

# %%
path_prefix = "/kaggle/input/eedi-mining-misconceptions-in-mathematics"
model_path = "/kaggle/input/sfr-embedding-mistral/SFR-Embedding-2_R"
lora_path="/kaggle/input/v7-recall/epoch_19_model/adapter.bin"
device='cuda:0'

# %%
tokenizer = AutoTokenizer.from_pretrained(lora_path.replace("/adapter.bin",""))
bnb_config = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_use_double_quant=True,
            bnb_4bit_quant_type="nf4",
            bnb_4bit_compute_dtype=torch.bfloat16
        )
backbone = AutoModel.from_pretrained(model_path, quantization_config=bnb_config,device_map=device)
config = LoraConfig(
        r=64,
        lora_alpha=128,
        target_modules=[
            "q_proj",
            "k_proj",
            "v_proj",
            "o_proj",
            "gate_proj",
            "up_proj",
            "down_proj",
        ],
        bias="none",
        lora_dropout=0.05,  # Conventional
        task_type="CAUSAL_LM",
    )
model = get_peft_model(backbone, config)
d = torch.load(lora_path, map_location=model.device)
model.load_state_dict(d, strict=False)
model = model.eval()
model = model.to(device)
print("Finish Loading Model")
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Finish Loading Model

# %%
import numpy as np
from tqdm.autonotebook import trange


task_description = 'Given a math question and a misconcepte incorrect answer, please retrieve the most accurate reason for the misconception.'

print("Start calculate Query embedding")
V_answer = inference(df, model, tokenizer, device)
print(f"Query embedding {V_answer.shape}")
np.save("/kaggle/working/train_query_embedding.npy", V_answer)

misconception_df = pd.read_csv("/kaggle/input/eedi-mining-misconceptions-in-mathematics/misconception_mapping.csv")
misconception_df["query_text"] = misconception_df["MisconceptionName"]

print("Start calculate Misconceptions embedding")
V_misconception = inference(misconception_df, model, tokenizer, device)
print(f"Misconception embedding {V_misconception.shape}")
np.save("/kaggle/working/misconception_embedding.npy", V_misconception)
# Out:
# Start calculate Query embedding
# Batches:   0%|          | 0/274 [00:00<?, ?it/s]
# Processing batch 0/4370
# Processing batch 16/4370
# Processing batch 32/4370
# Processing batch 48/4370
# Processing batch 64/4370
# Processing batch 80/4370
# Processing batch 96/4370
# Processing batch 112/4370
# Processing batch 128/4370
# Processing batch 144/4370
# Processing batch 160/4370
# Processing batch 176/4370
# Processing batch 192/4370
# Processing batch 208/4370
# Processing batch 224/4370
# Processing batch 240/4370
# Processing batch 256/4370
# Processing batch 272/4370
# Processing batch 288/4370
# Processing batch 304/4370
# Processing batch 320/4370
# Processing batch 336/4370
# Processing batch 352/4370
# Processing batch 368/4370
# Processing batch 384/4370
# Processing batch 400/4370
# Processing batch 416/4370
# Processing batch 432/4370
# Processing batch 448/4370
# Processing batch 464/4370
# Processing batch 480/4370
# Processing batch 496/4370
# Processing batch 512/4370
# Processing batch 528/4370
# Processing batch 544/4370
# Processing batch 560/4370
# Processing batch 576/4370
# Processing batch 592/4370
# Processing batch 608/4370
# Processing batch 624/4370
# Processing batch 640/4370
# Processing batch 656/4370
# Processing batch 672/4370
# Processing batch 688/4370
# Processing batch 704/4370
# Processing batch 720/4370
# Processing batch 736/4370
# Processing batch 752/4370
# Processing batch 768/4370
# Processing batch 784/4370
# Processing batch 800/4370
# Processing batch 816/4370
# Processing batch 832/4370
# Processing batch 848/4370
# Processing batch 864/4370
# Processing batch 880/4370
# Processing batch 896/4370
# Processing batch 912/4370
# Processing batch 928/4370
# Processing batch 944/4370
# Processing batch 960/4370
# Processing batch 976/4370
# Processing batch 992/4370
# Processing batch 1008/4370
# Processing batch 1024/4370
# Processing batch 1040/4370
# Processing batch 1056/4370
# Processing batch 1072/4370
# Processing batch 1088/4370
# Processing batch 1104/4370
# Processing batch 1120/4370
# Processing batch 1136/4370
# Processing batch 1152/4370
# Processing batch 1168/4370
# Processing batch 1184/4370
# Processing batch 1200/4370
# Processing batch 1216/4370
# Processing batch 1232/4370
# Processing batch 1248/4370
# Processing batch 1264/4370
# Processing batch 1280/4370
# Processing batch 1296/4370
# Processing batch 1312/4370
# Processing batch 1328/4370
# Processing batch 1344/4370
# Processing batch 1360/4370
# Processing batch 1376/4370
# Processing batch 1392/4370
# Processing batch 1408/4370
# Processing batch 1424/4370
# Processing batch 1440/4370
# Processing batch 1456/4370
# Processing batch 1472/4370
# Processing batch 1488/4370
# Processing batch 1504/4370
# Processing batch 1520/4370
# Processing batch 1536/4370
# Processing batch 1552/4370
# Processing batch 1568/4370
# Processing batch 1584/4370
# Processing batch 1600/4370
# Processing batch 1616/4370
# Processing batch 1632/4370
# Processing batch 1648/4370
# Processing batch 1664/4370
# Processing batch 1680/4370
# Processing batch 1696/4370
# Processing batch 1712/4370
# Processing batch 1728/4370
# Processing batch 1744/4370
# Processing batch 1760/4370
# Processing batch 1776/4370
# Processing batch 1792/4370
# Processing batch 1808/4370
# Processing batch 1824/4370
# Processing batch 1840/4370
# Processing batch 1856/4370
# Processing batch 1872/4370
# Processing batch 1888/4370
# Processing batch 1904/4370
# Processing batch 1920/4370
# Processing batch 1936/4370
# Processing batch 1952/4370
# Processing batch 1968/4370
# Processing batch 1984/4370
# Processing batch 2000/4370
# Processing batch 2016/4370
# Processing batch 2032/4370
# Processing batch 2048/4370
# Processing batch 2064/4370
# Processing batch 2080/4370
# Processing batch 2096/4370
# Processing batch 2112/4370
# Processing batch 2128/4370
# Processing batch 2144/4370
# Processing batch 2160/4370
# Processing batch 2176/4370
# Processing batch 2192/4370
# Processing batch 2208/4370
# Processing batch 2224/4370
# Processing batch 2240/4370
# Processing batch 2256/4370
# Processing batch 2272/4370
# Processing batch 2288/4370
# Processing batch 2304/4370
# Processing batch 2320/4370
# Processing batch 2336/4370
# Processing batch 2352/4370
# Processing batch 2368/4370
# Processing batch 2384/4370
# Processing batch 2400/4370
# Processing batch 2416/4370
# Processing batch 2432/4370
# Processing batch 2448/4370
# Processing batch 2464/4370
# Processing batch 2480/4370
# Processing batch 2496/4370
# Processing batch 2512/4370
# Processing batch 2528/4370
# Processing batch 2544/4370
# Processing batch 2560/4370
# Processing batch 2576/4370
# Processing batch 2592/4370
# Processing batch 2608/4370
# Processing batch 2624/4370
# Processing batch 2640/4370
# Processing batch 2656/4370
# Processing batch 2672/4370
# Processing batch 2688/4370
# Processing batch 2704/4370
# Processing batch 2720/4370
# Processing batch 2736/4370
# Processing batch 2752/4370
# Processing batch 2768/4370
# Processing batch 2784/4370
# Processing batch 2800/4370
# Processing batch 2816/4370
# Processing batch 2832/4370
# Processing batch 2848/4370
# Processing batch 2864/4370
# Processing batch 2880/4370
# Processing batch 2896/4370
# Processing batch 2912/4370
# Processing batch 2928/4370
# Processing batch 2944/4370
# Processing batch 2960/4370
# Processing batch 2976/4370
# Processing batch 2992/4370
# Processing batch 3008/4370
# Processing batch 3024/4370
# Processing batch 3040/4370
# Processing batch 3056/4370
# Processing batch 3072/4370
# Processing batch 3088/4370
# Processing batch 3104/4370
# Processing batch 3120/4370
# Processing batch 3136/4370
# Processing batch 3152/4370
# Processing batch 3168/4370
# Processing batch 3184/4370
# Processing batch 3200/4370
# Processing batch 3216/4370
# Processing batch 3232/4370
# Processing batch 3248/4370
# Processing batch 3264/4370
# Processing batch 3280/4370
# Processing batch 3296/4370
# Processing batch 3312/4370
# Processing batch 3328/4370
# Processing batch 3344/4370
# Processing batch 3360/4370
# Processing batch 3376/4370
# Processing batch 3392/4370
# Processing batch 3408/4370
# Processing batch 3424/4370
# Processing batch 3440/4370
# Processing batch 3456/4370
# Processing batch 3472/4370
# Processing batch 3488/4370
# Processing batch 3504/4370
# Processing batch 3520/4370
# Processing batch 3536/4370
# Processing batch 3552/4370
# Processing batch 3568/4370
# Processing batch 3584/4370
# Processing batch 3600/4370
# Processing batch 3616/4370
# Processing batch 3632/4370
# Processing batch 3648/4370
# Processing batch 3664/4370
# Processing batch 3680/4370
# Processing batch 3696/4370
# Processing batch 3712/4370
# Processing batch 3728/4370
# Processing batch 3744/4370
# Processing batch 3760/4370
# Processing batch 3776/4370
# Processing batch 3792/4370
# Processing batch 3808/4370
# Processing batch 3824/4370
# Processing batch 3840/4370
# Processing batch 3856/4370
# Processing batch 3872/4370
# Processing batch 3888/4370
# Processing batch 3904/4370
# Processing batch 3920/4370
# Processing batch 3936/4370
# Processing batch 3952/4370
# Processing batch 3968/4370
# Processing batch 3984/4370
# Processing batch 4000/4370
# Processing batch 4016/4370
# Processing batch 4032/4370
# Processing batch 4048/4370
# Processing batch 4064/4370
# Processing batch 4080/4370
# Processing batch 4096/4370
# Processing batch 4112/4370
# Processing batch 4128/4370
# Processing batch 4144/4370
# Processing batch 4160/4370
# Processing batch 4176/4370
# Processing batch 4192/4370
# Processing batch 4208/4370
# Processing batch 4224/4370
# Processing batch 4240/4370
# Processing batch 4256/4370
# Processing batch 4272/4370
# Processing batch 4288/4370
# Processing batch 4304/4370
# Processing batch 4320/4370
# Processing batch 4336/4370
# Processing batch 4352/4370
# Processing batch 4368/4370
# Query embedding (4370, 4096)
# Start calculate Misconceptions embedding
# Batches:   0%|          | 0/162 [00:00<?, ?it/s]
# Processing batch 0/2587
# Processing batch 16/2587
# Processing batch 32/2587
# Processing batch 48/2587
# Processing batch 64/2587
# Processing batch 80/2587
# Processing batch 96/2587
# Processing batch 112/2587
# Processing batch 128/2587
# Processing batch 144/2587
# Processing batch 160/2587
# Processing batch 176/2587
# Processing batch 192/2587
# Processing batch 208/2587
# Processing batch 224/2587
# Processing batch 240/2587
# Processing batch 256/2587
# Processing batch 272/2587
# Processing batch 288/2587
# Processing batch 304/2587
# Processing batch 320/2587
# Processing batch 336/2587
# Processing batch 352/2587
# Processing batch 368/2587
# Processing batch 384/2587
# Processing batch 400/2587
# Processing batch 416/2587
# Processing batch 432/2587
# Processing batch 448/2587
# Processing batch 464/2587
# Processing batch 480/2587
# Processing batch 496/2587
# Processing batch 512/2587
# Processing batch 528/2587
# Processing batch 544/2587
# Processing batch 560/2587
# Processing batch 576/2587
# Processing batch 592/2587
# Processing batch 608/2587
# Processing batch 624/2587
# Processing batch 640/2587
# Processing batch 656/2587
# Processing batch 672/2587
# Processing batch 688/2587
# Processing batch 704/2587
# Processing batch 720/2587
# Processing batch 736/2587
# Processing batch 752/2587
# Processing batch 768/2587
# Processing batch 784/2587
# Processing batch 800/2587
# Processing batch 816/2587
# Processing batch 832/2587
# Processing batch 848/2587
# Processing batch 864/2587
# Processing batch 880/2587
# Processing batch 896/2587
# Processing batch 912/2587
# Processing batch 928/2587
# Processing batch 944/2587
# Processing batch 960/2587
# Processing batch 976/2587
# Processing batch 992/2587
# Processing batch 1008/2587
# Processing batch 1024/2587
# Processing batch 1040/2587
# Processing batch 1056/2587
# Processing batch 1072/2587
# Processing batch 1088/2587
# Processing batch 1104/2587
# Processing batch 1120/2587
# Processing batch 1136/2587
# Processing batch 1152/2587
# Processing batch 1168/2587
# Processing batch 1184/2587
# Processing batch 1200/2587
# Processing batch 1216/2587
# Processing batch 1232/2587
# Processing batch 1248/2587
# Processing batch 1264/2587
# Processing batch 1280/2587
# Processing batch 1296/2587
# Processing batch 1312/2587
# Processing batch 1328/2587
# Processing batch 1344/2587
# Processing batch 1360/2587
# Processing batch 1376/2587
# Processing batch 1392/2587
# Processing batch 1408/2587
# Processing batch 1424/2587
# Processing batch 1440/2587
# Processing batch 1456/2587
# Processing batch 1472/2587
# Processing batch 1488/2587
# Processing batch 1504/2587
# Processing batch 1520/2587
# Processing batch 1536/2587
# Processing batch 1552/2587
# Processing batch 1568/2587
# Processing batch 1584/2587
# Processing batch 1600/2587
# Processing batch 1616/2587
# Processing batch 1632/2587
# Processing batch 1648/2587
# Processing batch 1664/2587
# Processing batch 1680/2587
# Processing batch 1696/2587
# Processing batch 1712/2587
# Processing batch 1728/2587
# Processing batch 1744/2587
# Processing batch 1760/2587
# Processing batch 1776/2587
# Processing batch 1792/2587
# Processing batch 1808/2587
# Processing batch 1824/2587
# Processing batch 1840/2587
# Processing batch 1856/2587
# Processing batch 1872/2587
# Processing batch 1888/2587
# Processing batch 1904/2587
# Processing batch 1920/2587
# Processing batch 1936/2587
# Processing batch 1952/2587
# Processing batch 1968/2587
# Processing batch 1984/2587
# Processing batch 2000/2587
# Processing batch 2016/2587
# Processing batch 2032/2587
# Processing batch 2048/2587
# Processing batch 2064/2587
# Processing batch 2080/2587
# Processing batch 2096/2587
# Processing batch 2112/2587
# Processing batch 2128/2587
# Processing batch 2144/2587
# Processing batch 2160/2587
# Processing batch 2176/2587
# Processing batch 2192/2587
# Processing batch 2208/2587
# Processing batch 2224/2587
# Processing batch 2240/2587
# Processing batch 2256/2587
# Processing batch 2272/2587
# Processing batch 2288/2587
# Processing batch 2304/2587
# Processing batch 2320/2587
# Processing batch 2336/2587
# Processing batch 2352/2587
# Processing batch 2368/2587
# Processing batch 2384/2587
# Processing batch 2400/2587
# Processing batch 2416/2587
# Processing batch 2432/2587
# Processing batch 2448/2587
# Processing batch 2464/2587
# Processing batch 2480/2587
# Processing batch 2496/2587
# Processing batch 2512/2587
# Processing batch 2528/2587
# Processing batch 2544/2587
# Processing batch 2560/2587
# Processing batch 2576/2587
# Misconception embedding (2587, 4096)
